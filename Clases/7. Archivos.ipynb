# %% [markdown]
# Archivos

# %%
# importar librerías
import pandas as pd
import numpy as np

# %% [markdown]
# Leer csv

# %%
# leer dataframe
df1=pd.read_csv('datasets/athlete_events.csv')
df2=pd.read_csv('datasets/PopularCreativeTypes.csv')

# %%
df1.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df2.head()
# Out:
#    RANK        CREATIVE TYPES MOVIES      TOTAL GROSS AVERAGE GROSS  \
# 0   1.0  Contemporary Fiction  7,442  $96,203,727,036   $12,927,133
# 1   2.0          Kids Fiction    564  $32,035,539,746   $56,800,602
# 2   3.0       Science Fiction    724  $29,922,660,857   $41,329,642
# 3   4.0               Fantasy    759  $21,724,062,575   $28,621,953
# 4   5.0            Super Hero    129  $20,273,157,911  $157,156,263
#
#   MARKET SHARE
# 0       40.46%
# 1       13.47%
# 2       12.59%
# 3        9.14%
# 4        8.53%

# %%
print(df1.Games.unique().tolist())
# Out:
# ['1992 Summer', '2012 Summer', '1920 Summer', '1900 Summer', '1988 Winter', '1992 Winter', '1994 Winter', '1932 Summer', '2002 Winter', '1952 Summer', '1980 Winter', '2000 Summer', '1996 Summer', '1912 Summer', '1924 Summer', '2014 Winter', '1948 Summer', '1998 Winter', '2006 Winter', '2008 Summer', '2016 Summer', '2004 Summer', '1960 Winter', '1964 Winter', '1984 Winter', '1984 Summer', '1968 Summer', '1972 Summer', '1988 Summer', '1936 Summer', '1952 Winter', '1956 Winter', '1956 Summer', '1960 Summer', '1928 Summer', '1976 Summer', '1980 Summer', '1964 Summer', '2010 Winter', '1968 Winter', '1906 Summer', '1972 Winter', '1976 Winter', '1924 Winter', '1904 Summer', '1928 Winter', '1908 Summer', '1948 Winter', '1932 Winter', '1936 Winter', '1896 Summer']

# %%
datos_judo=df1.loc[df1.Sport=='Judo']
datos_judo
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 1            2                   A Lamusi   M  23.0   170.0    60.0
# 160         64             M'Bairo Abakar   M  31.0     NaN     NaN
# 180         78               Salim Abanoz   M  26.0     NaN     NaN
# 412        229       Mohamed Ali Abdelaal   M  26.0   175.0    81.0
# 435        242          Ahmed Abdelrahman   M  20.0   165.0    60.0
# ...        ...                        ...  ..   ...     ...     ...
# 270853  135459             Oleg Zurabiani   M  19.0   172.0    64.0
# 270918  135482                Goran uvela   M  27.0   184.0    93.0
# 270981  135503            Zurab Zviadauri   M  23.0   182.0    90.0
# 271032  135535  Claudia Antoinette Zwiers   F  22.0   181.0    78.0
# 271033  135535  Claudia Antoinette Zwiers   F  30.0   181.0    78.0
#
#                 Team  NOC        Games  Year  Season            City Sport  \
# ...

# %%
datos_judo.Sex.count()
# Out:
# 3801

# %%
datos_judo.Sex.value_counts()
# Out:
# M    2708
# F    1093
# Name: Sex, dtype: int64

# %%
datos_judo.Age.max()
# Out:
# 43.0

# %%
datos_judo.Age.min()
# Out:
# 14.0

# %%
datos_judo[datos_judo.Age==15]
# Out:
#            ID                    Name Sex   Age  Height  Weight  Team  NOC  \
# 143860  72214  Erin Marc Kwai-lin Lum   F  15.0     NaN     NaN  Guam  GUM
#
#               Games  Year  Season       City Sport                      Event  \
# 143860  1992 Summer  1992  Summer  Barcelona  Judo  Judo Women's Middleweight
#
#        Medal
# 143860   NaN

# %%
datos_judo[datos_judo.Age==43]
# Out:
#            ID                       Name Sex   Age  Height  Weight  \
# 145940  73239  Orlando Madrigal Valverde   M  43.0   163.0    78.0
#
#               Team  NOC        Games  Year  Season   City Sport  \
# 145940  Costa Rica  CRC  1964 Summer  1964  Summer  Tokyo  Judo
#
#                           Event Medal
# 145940  Judo Men's Middleweight   NaN

# %%
ord_weight=datos_judo.sort_values(by=['Weight'])
ord_weight
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 247906  124131                        Vn Ngc T   F  24.0   158.0    46.0
# 247907  124131                        Vn Ngc T   F  28.0   158.0    46.0
# 95034    48120                     Joyce Heron   F  31.0   147.0    47.0
# 155619   78116            Lauren Michele Meece   F  17.0   157.0    48.0
# 30495    15722  Lyubov Aleksandrovna Bruletova   F  26.0   150.0    48.0
# ...        ...                             ...  ..   ...     ...     ...
# 264797  132515                    Yang Jong-Ok   M  28.0     NaN     NaN
# 266508  133320                      Yu Hui-Jun   F  19.0     NaN     NaN
# 266614  133371                    Yu Wai Seung   F  20.0     NaN     NaN
# 266781  133466                       Yun Hyeon   M  26.0     NaN     NaN
# 266812  133484                    Yun Sang-Sik   M  23.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season            City Sport  \
# ...

# %%
ord_age=datos_judo.sort_values(by=['Age'])
ord_age
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 46169    23829              Ludmila Cristea   F  14.0   165.0    55.0
# 143860   72214       Erin Marc Kwai-lin Lum   F  15.0     NaN     NaN
# 267755  133947           Danielle Zangrando   F  16.0   162.0    57.0
# 167582   84197                  Zsuzsa Nagy   F  16.0   178.0    64.0
# 209342  105110  Ronny Eduardo Sanabria Mora   M  16.0   167.0    57.0
# ...        ...                          ...  ..   ...     ...     ...
# 219279  110161               Henry Sichalwe   M   NaN     NaN    78.0
# 220493  110744                Philippe Simo   M   NaN   177.0    78.0
# 225584  113358           Carlos Soto Molina   M   NaN     NaN     NaN
# 237494  119119                  Asafu Tembo   M   NaN     NaN    78.0
# 262259  131223              Christophe Wogo   M   NaN   164.0    72.0
#
#                        Team  NOC        Games  Year  Season         City  \
# ...

# %%
ord_age[ord_age.Age.notna()]
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 46169    23829              Ludmila Cristea   F  14.0   165.0    55.0
# 143860   72214       Erin Marc Kwai-lin Lum   F  15.0     NaN     NaN
# 267755  133947           Danielle Zangrando   F  16.0   162.0    57.0
# 167582   84197                  Zsuzsa Nagy   F  16.0   178.0    64.0
# 209342  105110  Ronny Eduardo Sanabria Mora   M  16.0   167.0    57.0
# ...        ...                          ...  ..   ...     ...     ...
# 142431   71462       Sandro Luis Lpez Olmos   M  40.0   190.0   120.0
# 233959  117345                 Miklos Szabo   M  40.0   178.0   108.0
# 38118    19587   Carmen Anita Chal Quilumba   F  42.0   176.0   107.0
# 153789   77183               Jos Mba Nchama   M  42.0     NaN    81.0
# 145940   73239    Orlando Madrigal Valverde   M  43.0   163.0    78.0
#
#                      Team  NOC        Games  Year  Season       City Sport  \
# ...

# %%
sample=df1.loc[(df1.Age.notna())&(df1.Medal.notna())]
sample
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
df_oro=df.loc[df.Medal=='Gold']
df_oro.Age.min()
# Out:
# 13.0

# %%
df_oro=df.loc[df.Medal=='Gold']
df_joven=df_oro.loc[df_oro.Age==df_oro.Age.min(),['Name','Age','Medal']]
df_joven
# Out:
#                                       Name   Age Medal
# 27207                        Hans Bourquin  13.0  Gold
# 52010   Donna Elizabeth de Varona (-Pinto)  13.0  Gold
# 73581                           Fu Mingxia  13.0  Gold
# 78544         Marjorie Gestring (-Redlick)  13.0  Gold
# 119277                          Kim Yun-Mi  13.0  Gold
# 200704       Aileen Muriel Riggin (-Soule)  13.0  Gold
# 268602                         Klaus Zerta  13.0  Gold

# %%
df_medal=df.loc[df.Medal.notna()]

# %%
df.loc[df.Medal.notna()].max()
# Out:
# ID                                           135563
# Name                               ystein Pettersen
# Sex                                               M
# Age                                              73
# Height                                          223
# Weight                                          182
# Team                                            Zut
# NOC                                             ZIM
# Games                                   2016 Summer
# Year                                           2016
# Season                                       Winter
# City                                      Vancouver
# Sport                                     Wrestling
# Event     Wrestling Women's Middleweight, Freestyle
# Medal                                        Silver
# dtype: object

# %%
nombre=df_medal.Name.value_counts().index[0]

# %%
df_medal[df_medal.Name==nombre].to_dict('record')[0]
# Out:
# {'ID': 94406,
#  'Name': 'Michael Fred Phelps, II',
#  'Sex': 'M',
#  'Age': 19.0,
#  'Height': 193.0,
#  'Weight': 91.0,
#  'Team': 'United States',
#  'NOC': 'USA',
#  'Games': '2004 Summer',
#  'Year': 2004,
#  'Season': 'Summer',
#  'City': 'Athina',
#  'Sport': 'Swimming',
#  'Event': "Swimming Men's 200 metres Freestyle",
#  'Medal': 'Bronze'}
